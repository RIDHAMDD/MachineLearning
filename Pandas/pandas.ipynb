# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
mydata = pd.read_csv("Desktop/Books/CS317/cropyields.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 mydata = pd.read_csv("Desktop/Books/CS317/cropyields.csv")
#
# NameError: name 'pd' is not defined

# %%
#Answer 1
mydata["SUBJECT"].unique()

# %%
#Answer 1
mydata["TIME"].unique()

# %%
# !pip3 install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
data = mydata[mydata["TIME"] == 1990]['Value']

# %%
data
# Out:
# 0        8.315
# 41       1.634
# 82       0.000
# 123      2.277
# 164      4.586
#          ...
# 18471    0.000
# 18512    0.000
# 18553    0.000
# 18594    0.000
# 18635    0.000
# Name: Value, Length: 455, dtype: float64

# %%
#answer2 (Matplotlib’s ‘pyplot.hist’)
plt.hist(data)
plt.xlabel("Crop Yields")
plt.ylabel("Length")
plt.title('Histogram of the distribution of the Value column in the year 1990.')
plt.show()

# %%
mydata2 = mydata[(mydata["TIME"] == 1990)]['Value']

# %%
mydata2
# Out:
# 0        8.315
# 41       1.634
# 82       0.000
# 123      2.277
# 164      4.586
#          ...
# 18471    0.000
# 18512    0.000
# 18553    0.000
# 18594    0.000
# 18635    0.000
# Name: Value, Length: 455, dtype: float64

# %%
import pylab as pl

# %%
#answer2  (pandas way)
mydata2.hist()
pl.title("Histogram of the distribution of the Value column in the year 1990.")
pl.xlabel("Crop Yields")
pl.ylabel("Length")
# Out:
# Text(0, 0.5, 'Length')

# %%
#answer 3
mydata["MEASURE"].unique()
# Out:
# array(['TONNE_HA', 'THND_TONNE', 'THND_HA'], dtype=object)

# %%
mydata3 = mydata["MEASURE"]

# %%
#answer 3 (Frequency distribution)
mydata3.value_counts()
# Out:
# MEASURE
# THND_TONNE    6232
# THND_HA       6232
# TONNE_HA      6212
# Name: count, dtype: int64

# %%
#answer 3
# Tonne/HA means yield in tonnes by the area in hectares
# THND_HA means total area of land that was harvested
# THND_Tonne means total quantity of the crop produced

# %%
mydata4 = mydata[mydata["MEASURE"] == 'TONNE_HA']

# %%
mydata4
#Answer 3
#yields per hectare dataset
# Out:
#       LOCATION  INDICATOR  SUBJECT   MEASURE FREQUENCY  TIME  Value  \
# 0          AUS  CROPYIELD     RICE  TONNE_HA         A  1990  8.315
# 1          AUS  CROPYIELD     RICE  TONNE_HA         A  1991  8.395
# 2          AUS  CROPYIELD     RICE  TONNE_HA         A  1992  8.094
# 3          AUS  CROPYIELD     RICE  TONNE_HA         A  1993  8.336
# 4          AUS  CROPYIELD     RICE  TONNE_HA         A  1994  8.538
# ...        ...        ...      ...       ...       ...   ...    ...
# 18589      GBR  CROPYIELD  SOYBEAN  TONNE_HA         A  2026  0.000
# 18590      GBR  CROPYIELD  SOYBEAN  TONNE_HA         A  2027  0.000
# 18591      GBR  CROPYIELD  SOYBEAN  TONNE_HA         A  2028  0.000
# 18592      GBR  CROPYIELD  SOYBEAN  TONNE_HA         A  2029  0.000
# 18593      GBR  CROPYIELD  SOYBEAN  TONNE_HA         A  2030  0.000
#
#        Flag Codes
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# ...

# %%
mydata5 = mydata4[(mydata4["SUBJECT"] == 'RICE') & (mydata4["TIME"] == 2020)]

# %%
mydata5
# Out:
#       LOCATION  INDICATOR SUBJECT   MEASURE FREQUENCY  TIME  Value  Flag Codes
# 30         AUS  CROPYIELD    RICE  TONNE_HA         A  2020  8.305         NaN
# 112        CAN  CROPYIELD    RICE  TONNE_HA         A  2020  0.000         NaN
# 194        JPN  CROPYIELD    RICE  TONNE_HA         A  2020  5.032         NaN
# 276        KOR  CROPYIELD    RICE  TONNE_HA         A  2020  5.474         NaN
# 358        MEX  CROPYIELD    RICE  TONNE_HA         A  2020  6.682         NaN
# 481        TUR  CROPYIELD    RICE  TONNE_HA         A  2020  4.781         NaN
# 563        USA  CROPYIELD    RICE  TONNE_HA         A  2020  5.477         NaN
# 645        ARG  CROPYIELD    RICE  TONNE_HA         A  2020  4.387         NaN
# 727        BRA  CROPYIELD    RICE  TONNE_HA         A  2020  4.565         NaN
# 809        CHL  CROPYIELD    RICE  TONNE_HA         A  2020  4.454         NaN
# 891        CHN  CROPYIELD    RICE  TONNE_HA         A  2020  4.931         NaN
# ...

# %%
#Answer 4
#boxplot of the crop yield of rice in
#tons per hectare for all countries in the year 2020.
plt.boxplot(mydata5['Value'])
plt.xlabel("yield of rice")
plt.ylabel("Value")
plt.title("Boxplot of the crop yield of rice in tons per hectare for all countries in the year 2020")
plt.show()

# %%
mydata6 = mydata5.sort_values('Value', ascending=False)

# %%
mydata6
# Out:
#       LOCATION  INDICATOR SUBJECT   MEASURE FREQUENCY  TIME  Value  Flag Codes
# 30         AUS  CROPYIELD    RICE  TONNE_HA         A  2020  8.305         NaN
# 358        MEX  CROPYIELD    RICE  TONNE_HA         A  2020  6.682         NaN
# 1055       EGY  CROPYIELD    RICE  TONNE_HA         A  2020  6.447         NaN
# 2039       RUS  CROPYIELD    RICE  TONNE_HA         A  2020  5.749         NaN
# 563        USA  CROPYIELD    RICE  TONNE_HA         A  2020  5.477         NaN
# 276        KOR  CROPYIELD    RICE  TONNE_HA         A  2020  5.474         NaN
# 1875       PER  CROPYIELD    RICE  TONNE_HA         A  2020  5.424         NaN
# 194        JPN  CROPYIELD    RICE  TONNE_HA         A  2020  5.032         NaN
# 891        CHN  CROPYIELD    RICE  TONNE_HA         A  2020  4.931         NaN
# 2613      OECD  CROPYIELD    RICE  TONNE_HA         A  2020  4.902         NaN
# 481        TUR  CROPYIELD    RICE  TONNE_HA         A  2020  4.781         NaN
# ...

# %%
# Answer 5) Highest yeild was 8.305 tonne/Hectare and was by country Australia

# %%
import matplotlib.pyplot as plt

# %%
mydata7 = mydata4[mydata4["LOCATION"] == 'USA']

# %%
mydata7
# Out:
#       LOCATION  INDICATOR SUBJECT   MEASURE FREQUENCY  TIME   Value  \
# 533        USA  CROPYIELD    RICE  TONNE_HA         A  1990   4.314
# 534        USA  CROPYIELD    RICE  TONNE_HA         A  1991   4.469
# 535        USA  CROPYIELD    RICE  TONNE_HA         A  1992   4.473
# 536        USA  CROPYIELD    RICE  TONNE_HA         A  1993   4.301
# 537        USA  CROPYIELD    RICE  TONNE_HA         A  1994   4.651
# ...        ...        ...     ...       ...       ...   ...     ...
# 16826      USA  CROPYIELD   MAIZE  TONNE_HA         A  2026  11.307
# 16827      USA  CROPYIELD   MAIZE  TONNE_HA         A  2027  11.377
# 16828      USA  CROPYIELD   MAIZE  TONNE_HA         A  2028  11.442
# 16829      USA  CROPYIELD   MAIZE  TONNE_HA         A  2029  11.504
# 16830      USA  CROPYIELD   MAIZE  TONNE_HA         A  2030  11.565
#
#        Flag Codes
# 533           NaN
# 534           NaN
# 535           NaN
# 536           NaN
# 537           NaN
# ...           ...
# ...

# %%
#Answer 6
mydata7.boxplot(column='Value', by='SUBJECT') 
pl.xlabel("Grains")
pl.ylabel("Value")
pl.title("Comparative boxplot comparing the crop yield per hectare")
# Out:
# Text(0.5, 1.0, 'Comparative boxplot comparing the crop yield per hectare')
